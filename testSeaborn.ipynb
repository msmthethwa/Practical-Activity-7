# %%
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd

# %%
footBall = pd.read_csv("C:/Users/MS Mthethwa/Desktop/MUT/Programming (Year 2)/TECHNICAL PROGRAMMING II/Test/Test 1/dataset - 2020-09-24.csv")

# %%
print(footBall.columns)
# Out:
# Index(['Name', 'Jersey Number', 'Club', 'Position', 'Nationality', 'Age',
#        'Appearances', 'Wins', 'Losses', 'Goals', 'Goals per match',
#        'Headed goals', 'Goals with right foot', 'Goals with left foot',
#        'Penalties scored', 'Freekicks scored', 'Shots', 'Shots on target',
#        'Shooting accuracy %', 'Hit woodwork', 'Big chances missed',
#        'Clean sheets', 'Goals conceded', 'Tackles', 'Tackle success %',
#        'Last man tackles', 'Blocked shots', 'Interceptions', 'Clearances',
#        'Headed Clearance', 'Clearances off line', 'Recoveries', 'Duels won',
#        'Duels lost', 'Successful 50/50s', 'Aerial battles won',
#        'Aerial battles lost', 'Own goals', 'Errors leading to goal', 'Assists',
#        'Passes', 'Passes per match', 'Big chances created', 'Crosses',
#        'Cross accuracy %', 'Through balls', 'Accurate long balls', 'Saves',
#        'Penalties saved', 'Punches', 'High Claims', 'Catches',
# ...

# %%
print(footBall['Crosses'])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3      389.0
# 4       45.0
#        ...
# 566     52.0
# 567     57.0
# 568    327.0
# 569      0.0
# 570      0.0
# Name: Crosses, Length: 571, dtype: float64

# %%
sb.set_theme()
sb.set_style('whitegrid')
sb.set_context()
sb.lineplot(x='Goals with right foot', y='Goals with left foot', data=footBall)
plt.title('Goals Scored')
plt.show()

# %%
sb.distplot(footBall['Passes per match'])
# Out:
# C:\Users\MS Mthethwa\AppData\Local\Temp\ipykernel_13560\634201076.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(footBall['Passes per match'])
# <Axes: xlabel='Passes per match', ylabel='Density'>

# %%
sb.kdeplot(data = footBall['Big chances missed'], fill=True)
# Out:
# <Axes: xlabel='Big chances missed', ylabel='Density'>

# %%
sb.rugplot(footBall['Interceptions'])
# Out:
# <Axes: xlabel='Interceptions'>

# %%
sb.boxplot(x='Club', y='Wins', data=footBall.loc[:100])
# Out:
# <Axes: xlabel='Club', ylabel='Wins'>

# %%
sb.violinplot(x='Club', y='Wins', data=footBall.loc[:100])
# Out:
# <Axes: xlabel='Club', ylabel='Wins'>

# %%
sb.swarmplot(x='Club', y='Wins', data=footBall.loc[:100])
# Out:
# <Axes: xlabel='Club', ylabel='Wins'>

# %%
sb.pairplot(footBall, hue='Club')

# %%
sb.jointplot(x='Hit woodwork', y='Crosses', data=footBall, kind='scatter')
